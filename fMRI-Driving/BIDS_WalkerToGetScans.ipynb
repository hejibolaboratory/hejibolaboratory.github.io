# %%
def bids_scan_file_walker(dataset=".", include_types=None, warn_no_files=False):
    '''
    Traverse a BIDS dataset and provide a generator interface
    to the imaging files contained within.
    Arguments:
    dataset -- path to the BIDS dataset folder.
    Keyword Arguments:
    include_types -- a list of the scan types (i.e. subfolder names)
    to include in the results. Can be any combination of "func",
    "anat", "fmap", "dwi".
    warn_no_files -- issue a warning if no imaging files are found
    for a subject or a session.
    Returns:
    A list containing, for each .nii or .nii.gz file found, the BIDS
    identifying tokens and their values. If a file doesn't have an
    identifying token its key will be None.
    '''
    import os
    import os.path as op
    from glob import glob

    from warnings import warn
    def _no_files_warning(folder):
        if not warn_no_files:
            return
        warn("No files of requested type(s) found in scan folder: %s" \
               % folder, RuntimeWarning, stacklevel=1)

    def _walk_dir_for_prefix(target_dir, prefix):
        return [x for x in next(os.walk(target_dir))[1]
                if x.startswith(prefix)]

    def _tokenize_bids_scan_name(scanfile):
        scan_basename = op.splitext(op.split(scanfile)[1])[0]
        # .nii.gz will have .nii leftover
        scan_basename = scan_basename.replace(".nii", "")
        file_bits = scan_basename.split('_')

        # BIDS with non ses-* subfolders given default
        # "single_session" ses.
        file_tokens = {'scanfile': scanfile,
                       'sub': None, 'ses': "single_session",
                       'acq': None, 'rec': None,
                       'run': None, 'task': None,
                       'modality': file_bits[-1]}
        for bit in file_bits:
            for key in file_tokens.keys():
                if bit.startswith(key):
                    file_tokens[key] = bit

        return file_tokens

    #########

    if include_types is None:
        # include all scan types by default
        include_types = ['func', 'anat', 'fmap', 'dwi']

    subjects = _walk_dir_for_prefix(dataset, 'sub-')
    if len(subjects) == 0:
        raise GeneratorExit("No BIDS subjects found to examine.")

    # for each subject folder, look for scans considering explicitly
    # defined sessions or the implicit "single_session" case.
    for subject in subjects:
        subj_dir = op.join(dataset, subject)

        sessions = _walk_dir_for_prefix(subj_dir, 'ses-')

        for scan_type in include_types:
            # seems easier to consider the case of multi-session vs.
            # single session separately?
            if len(sessions) > 0:
                subject_sessions = [op.join(subject, x)
                                    for x in sessions]
            else:
                subject_sessions = [subject]

            for session in subject_sessions:

                scan_files = glob(op.join(
                    dataset, session, scan_type,
                    '*.nii*'))

                if len(scan_files) == 0:
                    _no_files_warning(session)

                for scan_file in scan_files:
                    yield _tokenize_bids_scan_name(scan_file)

# %%
bids_imgs = bids_scan_file_walker("..", include_types=['anat', 'func'])

# %%
file_info = []
for s in sorted(bids_imgs, key=lambda file: file['scanfile']):
    file_info.append(s)

# %%
file_info
# Out:
# [{'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-1/anat/sub-9001_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9001',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-1/anat/sub-9001_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9001',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-1/func/sub-9001_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9001',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-1/func/sub-9001_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9001',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-1/func/sub-9001_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9001',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-1/func/sub-9001_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9001',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-1/func/sub-9001_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9001',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-2/anat/sub-9001_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9001',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-2/func/sub-9001_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9001',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-2/func/sub-9001_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9001',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-2/func/sub-9001_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9001',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-2/func/sub-9001_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9001',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9001/ses-2/func/sub-9001_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9001',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-1/anat/sub-9002_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9002',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-1/anat/sub-9002_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9002',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-1/func/sub-9002_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9002',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-1/func/sub-9002_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9002',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-1/func/sub-9002_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9002',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-1/func/sub-9002_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9002',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-1/func/sub-9002_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9002',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-2/anat/sub-9002_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9002',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-2/func/sub-9002_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9002',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-2/func/sub-9002_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9002',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-2/func/sub-9002_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9002',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-2/func/sub-9002_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9002',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9002/ses-2/func/sub-9002_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9002',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-1/anat/sub-9003_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9003',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-1/anat/sub-9003_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9003',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-1/func/sub-9003_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9003',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-1/func/sub-9003_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9003',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-1/func/sub-9003_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9003',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-1/func/sub-9003_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9003',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-1/func/sub-9003_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9003',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-2/anat/sub-9003_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9003',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-2/func/sub-9003_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9003',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-2/func/sub-9003_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9003',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-2/func/sub-9003_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9003',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-2/func/sub-9003_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9003',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9003/ses-2/func/sub-9003_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9003',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-1/anat/sub-9004_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9004',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-1/anat/sub-9004_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9004',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-1/func/sub-9004_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9004',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-1/func/sub-9004_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9004',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-1/func/sub-9004_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9004',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-1/func/sub-9004_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9004',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-1/func/sub-9004_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9004',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-2/anat/sub-9004_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9004',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-2/func/sub-9004_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9004',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-2/func/sub-9004_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9004',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-2/func/sub-9004_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9004',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-2/func/sub-9004_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9004',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9004/ses-2/func/sub-9004_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9004',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-1/anat/sub-9005_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9005',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-1/anat/sub-9005_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9005',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-1/func/sub-9005_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9005',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-1/func/sub-9005_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9005',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-1/func/sub-9005_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9005',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-1/func/sub-9005_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9005',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-1/func/sub-9005_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9005',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-2/anat/sub-9005_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9005',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-2/func/sub-9005_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9005',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-2/func/sub-9005_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9005',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-2/func/sub-9005_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9005',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-2/func/sub-9005_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9005',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9005/ses-2/func/sub-9005_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9005',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-1/anat/sub-9007_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9007',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-1/anat/sub-9007_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9007',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-1/func/sub-9007_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9007',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-1/func/sub-9007_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9007',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-1/func/sub-9007_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9007',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-1/func/sub-9007_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9007',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-1/func/sub-9007_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9007',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-2/anat/sub-9007_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9007',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-2/func/sub-9007_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9007',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-2/func/sub-9007_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9007',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-2/func/sub-9007_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9007',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-2/func/sub-9007_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9007',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9007/ses-2/func/sub-9007_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9007',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-1/anat/sub-9008_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9008',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-1/anat/sub-9008_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9008',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-1/func/sub-9008_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9008',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-1/func/sub-9008_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9008',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-1/func/sub-9008_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9008',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-1/func/sub-9008_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9008',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-1/func/sub-9008_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9008',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-2/anat/sub-9008_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9008',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-2/func/sub-9008_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9008',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-2/func/sub-9008_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9008',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-2/func/sub-9008_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9008',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-2/func/sub-9008_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9008',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9008/ses-2/func/sub-9008_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9008',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-1/anat/sub-9009_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9009',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-1/anat/sub-9009_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9009',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-1/func/sub-9009_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9009',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-1/func/sub-9009_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9009',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-1/func/sub-9009_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9009',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-1/func/sub-9009_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9009',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-1/func/sub-9009_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9009',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-2/anat/sub-9009_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9009',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-2/func/sub-9009_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9009',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-2/func/sub-9009_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9009',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-2/func/sub-9009_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9009',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-2/func/sub-9009_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9009',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9009/ses-2/func/sub-9009_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9009',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9010/ses-1/anat/sub-9010_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9010',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9010/ses-1/anat/sub-9010_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9010',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9010/ses-1/func/sub-9010_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9010',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9010/ses-1/func/sub-9010_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9010',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9010/ses-1/func/sub-9010_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9010',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9010/ses-1/func/sub-9010_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9010',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9010/ses-1/func/sub-9010_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9010',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-1/anat/sub-9011_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9011',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-1/anat/sub-9011_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9011',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-1/func/sub-9011_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9011',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-1/func/sub-9011_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9011',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-1/func/sub-9011_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9011',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-1/func/sub-9011_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9011',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-1/func/sub-9011_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9011',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-2/anat/sub-9011_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9011',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-2/func/sub-9011_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9011',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-2/func/sub-9011_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9011',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-2/func/sub-9011_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9011',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-2/func/sub-9011_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9011',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9011/ses-2/func/sub-9011_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9011',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-1/anat/sub-9012_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9012',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-1/anat/sub-9012_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9012',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-1/func/sub-9012_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9012',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-1/func/sub-9012_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9012',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-1/func/sub-9012_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9012',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-1/func/sub-9012_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9012',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-1/func/sub-9012_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9012',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-2/anat/sub-9012_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9012',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-2/func/sub-9012_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9012',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-2/func/sub-9012_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9012',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-2/func/sub-9012_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9012',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-2/func/sub-9012_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9012',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9012/ses-2/func/sub-9012_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9012',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-1/anat/sub-9013_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9013',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-1/func/sub-9013_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9013',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-1/func/sub-9013_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9013',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-1/func/sub-9013_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9013',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-1/func/sub-9013_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9013',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-1/func/sub-9013_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9013',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-2/anat/sub-9013_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9013',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-2/anat/sub-9013_ses-2_T2w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9013',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-2/func/sub-9013_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9013',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-2/func/sub-9013_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9013',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-2/func/sub-9013_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9013',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-2/func/sub-9013_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9013',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9013/ses-2/func/sub-9013_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9013',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-1/anat/sub-9014_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9014',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-1/anat/sub-9014_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9014',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-1/func/sub-9014_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9014',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-1/func/sub-9014_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9014',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-1/func/sub-9014_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9014',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-1/func/sub-9014_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9014',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-1/func/sub-9014_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9014',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-2/anat/sub-9014_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9014',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-2/func/sub-9014_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9014',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-2/func/sub-9014_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9014',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-2/func/sub-9014_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9014',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-2/func/sub-9014_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9014',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9014/ses-2/func/sub-9014_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9014',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9016/ses-1/anat/sub-9016_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9016',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9016/ses-1/anat/sub-9016_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9016',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9016/ses-1/func/sub-9016_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9016',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9016/ses-1/func/sub-9016_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9016',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9016/ses-1/func/sub-9016_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9016',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9016/ses-1/func/sub-9016_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9016',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9016/ses-1/func/sub-9016_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9016',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-1/anat/sub-9017_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9017',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-1/anat/sub-9017_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9017',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-1/func/sub-9017_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9017',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-1/func/sub-9017_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9017',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-1/func/sub-9017_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9017',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-1/func/sub-9017_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9017',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-1/func/sub-9017_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9017',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-2/anat/sub-9017_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9017',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-2/func/sub-9017_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9017',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-2/func/sub-9017_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9017',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-2/func/sub-9017_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9017',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-2/func/sub-9017_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9017',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9017/ses-2/func/sub-9017_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9017',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-1/anat/sub-9018_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9018',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-1/anat/sub-9018_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9018',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-1/func/sub-9018_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9018',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-1/func/sub-9018_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9018',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-1/func/sub-9018_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9018',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-1/func/sub-9018_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9018',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-1/func/sub-9018_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9018',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-2/anat/sub-9018_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9018',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-2/func/sub-9018_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9018',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-2/func/sub-9018_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9018',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-2/func/sub-9018_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9018',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-2/func/sub-9018_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9018',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9018/ses-2/func/sub-9018_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9018',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-1/anat/sub-9019_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9019',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-1/anat/sub-9019_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9019',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-1/func/sub-9019_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9019',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-1/func/sub-9019_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9019',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-1/func/sub-9019_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9019',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-1/func/sub-9019_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9019',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-1/func/sub-9019_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9019',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-2/anat/sub-9019_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9019',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-2/func/sub-9019_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9019',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-2/func/sub-9019_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9019',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-2/func/sub-9019_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9019',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-2/func/sub-9019_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9019',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9019/ses-2/func/sub-9019_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9019',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-1/anat/sub-9020_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9020',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-1/anat/sub-9020_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9020',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-1/func/sub-9020_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9020',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-1/func/sub-9020_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9020',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-1/func/sub-9020_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9020',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-1/func/sub-9020_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9020',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-1/func/sub-9020_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9020',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-2/anat/sub-9020_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9020',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-2/func/sub-9020_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9020',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-2/func/sub-9020_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9020',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-2/func/sub-9020_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9020',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-2/func/sub-9020_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9020',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9020/ses-2/func/sub-9020_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9020',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9022/ses-1/anat/sub-9022_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9022',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9022/ses-1/anat/sub-9022_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9022',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9022/ses-1/func/sub-9022_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9022',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9022/ses-1/func/sub-9022_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9022',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9022/ses-1/func/sub-9022_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9022',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9022/ses-1/func/sub-9022_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9022',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9022/ses-1/func/sub-9022_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9022',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9023/ses-1/anat/sub-9023_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9023',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9023/ses-1/anat/sub-9023_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9023',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9023/ses-1/func/sub-9023_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9023',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9023/ses-1/func/sub-9023_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9023',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
# ...
#   'run': None,
#   'scanfile': '../sub-9084/ses-2/func/sub-9084_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9084',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9084/ses-2/func/sub-9084_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9084',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9084/ses-2/func/sub-9084_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9084',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9084/ses-2/func/sub-9084_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9084',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-1/anat/sub-9085_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9085',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-1/anat/sub-9085_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9085',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-1/func/sub-9085_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9085',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-1/func/sub-9085_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9085',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-1/func/sub-9085_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9085',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-1/func/sub-9085_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9085',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-1/func/sub-9085_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9085',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-2/anat/sub-9085_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9085',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-2/func/sub-9085_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9085',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-2/func/sub-9085_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9085',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-2/func/sub-9085_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9085',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-2/func/sub-9085_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9085',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9085/ses-2/func/sub-9085_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9085',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-1/anat/sub-9086_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9086',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-1/anat/sub-9086_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9086',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-1/func/sub-9086_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9086',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-1/func/sub-9086_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9086',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-1/func/sub-9086_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9086',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-1/func/sub-9086_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9086',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-1/func/sub-9086_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9086',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-2/anat/sub-9086_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9086',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-2/func/sub-9086_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9086',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-2/func/sub-9086_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9086',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-2/func/sub-9086_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9086',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-2/func/sub-9086_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9086',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9086/ses-2/func/sub-9086_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9086',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-1/anat/sub-9087_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9087',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-1/anat/sub-9087_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9087',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-1/func/sub-9087_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9087',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-1/func/sub-9087_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9087',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-1/func/sub-9087_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9087',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-1/func/sub-9087_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9087',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-1/func/sub-9087_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9087',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-2/anat/sub-9087_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9087',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-2/func/sub-9087_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9087',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-2/func/sub-9087_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9087',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-2/func/sub-9087_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9087',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-2/func/sub-9087_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9087',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9087/ses-2/func/sub-9087_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9087',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-1/anat/sub-9088_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9088',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-1/anat/sub-9088_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9088',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-1/func/sub-9088_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9088',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-1/func/sub-9088_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9088',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-1/func/sub-9088_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9088',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-1/func/sub-9088_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9088',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-1/func/sub-9088_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9088',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-2/anat/sub-9088_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9088',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-2/func/sub-9088_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9088',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-2/func/sub-9088_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9088',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-2/func/sub-9088_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9088',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-2/func/sub-9088_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9088',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9088/ses-2/func/sub-9088_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9088',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-1/anat/sub-9089_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9089',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-1/anat/sub-9089_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9089',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-1/func/sub-9089_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9089',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-1/func/sub-9089_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9089',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-1/func/sub-9089_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9089',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-1/func/sub-9089_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9089',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-1/func/sub-9089_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9089',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-2/anat/sub-9089_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9089',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-2/func/sub-9089_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9089',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-2/func/sub-9089_ses-2_task-faces_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9089',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-2/func/sub-9089_ses-2_task-hands_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9089',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-2/func/sub-9089_ses-2_task-rest_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9089',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9089/ses-2/func/sub-9089_ses-2_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9089',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9090/ses-1/anat/sub-9090_ses-1_T1w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9090',
#   'task': None},
#  {'acq': None,
#   'modality': 'T2w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9090/ses-1/anat/sub-9090_ses-1_T2w.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9090',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9090/ses-1/func/sub-9090_ses-1_task-arrows_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9090',
#   'task': 'task-arrows'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9090/ses-1/func/sub-9090_ses-1_task-faces_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9090',
#   'task': 'task-faces'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9090/ses-1/func/sub-9090_ses-1_task-hands_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9090',
#   'task': 'task-hands'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9090/ses-1/func/sub-9090_ses-1_task-rest_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9090',
#   'task': 'task-rest'},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9090/ses-1/func/sub-9090_ses-1_task-sleepiness_bold.nii.gz',
#   'ses': 'ses-1',
#   'sub': 'sub-9090',
#   'task': 'task-sleepiness'},
#  {'acq': None,
#   'modality': 'T1w',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9090/ses-2/anat/sub-9090_ses-2_T1w.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9090',
#   'task': None},
#  {'acq': None,
#   'modality': 'bold',
#   'rec': None,
#   'run': None,
#   'scanfile': '../sub-9090/ses-2/func/sub-9090_ses-2_task-arrows_bold.nii.gz',
#   'ses': 'ses-2',
#   'sub': 'sub-9090',
#   'task': 'task-arrows'},
#  ...]
